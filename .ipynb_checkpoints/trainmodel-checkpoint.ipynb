# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
from keras.preprocessing import image

batch_size = 10
img_height = 128
img_width = 128
data_dir = os.path.join(os.getcwd(), 'images', 'handsigns')
testdata_dir = os.path.join(os.getcwd(), 'images', 'testimages')
class_names = None

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 80 files belonging to 4 classes.
# Using 64 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 80 files belonging to 4 classes.
# Using 16 files for validation.

# %%
#test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  #testdata_dir,
  #image_size=(img_height, img_width),
  #batch_size=batch_size)

# %%
class_names = train_ds.class_names
print(class_names)
print(len(class_names))
# Out:
# ['coffeecup', 'handcream', 'honeyjar', 'teacup']
# 4

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (10, 128, 128, 3)
# (10,)

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 0.8117648

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=5
)
# Out:
# Epoch 1/5
# 7/7 [==============================] - 1s 36ms/step - loss: 1.3852 - accuracy: 0.2812 - val_loss: 1.3489 - val_accuracy: 0.3125
# Epoch 2/5
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2642 - accuracy: 0.3750 - val_loss: 1.1992 - val_accuracy: 0.6250
# Epoch 3/5
# 7/7 [==============================] - 0s 8ms/step - loss: 0.9159 - accuracy: 0.7656 - val_loss: 0.8207 - val_accuracy: 0.8125
# Epoch 4/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4554 - accuracy: 0.9219 - val_loss: 0.6428 - val_accuracy: 0.7500
# Epoch 5/5
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2925 - accuracy: 0.8906 - val_loss: 0.6483 - val_accuracy: 0.6875

# %%
model.evaluate(val_ds)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6483 - accuracy: 0.6875
# [0.6483453512191772, 0.6875]

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
individual_pics_test_path = os.path.join(os.getcwd(), 'images', 'testimages')
pic_list = os.listdir(individual_pics_test_path)
for picture in pic_list:
    test_image_path = os.path.join(individual_pics_test_path, picture)
    test_image = image.load_img(test_image_path, (img_height,img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image,axis=0)
    result = probability_model.predict(test_image)
    class_names[np.argmax(result)]
    print(class_names[np.argmax(result)] + " " + str(round((np.amax(result)*100), 2)) + " % ---- " + picture)
    #training_set.class_indices
# Out:
# coffeecup 99.99 % ---- coffeecup1c9a13b4-10ae-11ec-8ce8-2c4d544e1729.jpg
# coffeecup 71.46 % ---- coffeecup_90deg2c66b385-10ae-11ec-8e1a-2c4d544e1729.jpg
# handcream 90.25 % ---- handcream494528e8-10ae-11ec-a994-2c4d544e1729.jpg
# handcream 92.72 % ---- handcream_90deg51f83f93-10ae-11ec-8540-2c4d544e1729.jpg
# honeyjar 90.43 % ---- honeyjar0eff630d-10ae-11ec-82b0-2c4d544e1729.jpg
# coffeecup 91.69 % ---- random1afdec4a0-10b0-11ec-be4e-2c4d544e1729.jpg
# coffeecup 99.56 % ---- random2bf4c7fa0-10b0-11ec-8554-2c4d544e1729.jpg
# teacup 98.12 % ---- teacup3b027deb-10ae-11ec-af9a-2c4d544e1729.jpg

# %% [markdown]
# ###
